# %%
import sqlalchemy
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date as dt
#mostrar todas as colunas
pd.set_option('display.max_columns', None)

# %%
engine = sqlalchemy.create_engine('postgresql://1922120021_TCC_Tassio:1922120021_TCC_Tassio@3.133.102.60/IESB_Preco_Combustivel')
df = pd.read_sql_query("SELECT  * FROM combustiveis_analise", engine)

# %%
df
# Out:
#          uf       Municipio                                   Revenda  \
# 0        DF        BRASILIA  MAXPETRO COMAARCIO DE COMBUSTAAVEIS LTDA
# 1        RJ  RIO DE JANEIRO         SOL DA MANHA POSTO E GARAGEM LTDA
# 2        RJ  RIO DE JANEIRO         SOL DA MANHA POSTO E GARAGEM LTDA
# 3        RJ  RIO DE JANEIRO         SOL DA MANHA POSTO E GARAGEM LTDA
# 4        PR        LONDRINA     B R E COMAARCIO DE COMBUSTAAVEIS LTDA
# ...      ..             ...                                       ...
# 9612976  MG      PATROCINIO                 AUTO POSTO ECONOMICO LTDA
# 9612977  MG      PATROCINIO                 AUTO POSTO ECONOMICO LTDA
# 9612978  MG      PATROCINIO                 AUTO POSTO ECONOMICO LTDA
# 9612979  DF        BRASILIA  MAXPETRO COMAARCIO DE COMBUSTAAVEIS LTDA
# 9612980  DF        BRASILIA  MAXPETRO COMAARCIO DE COMBUSTAAVEIS LTDA
#
#              CNPJ_da_Revenda               Nome_da_Rua        Cep   Produto  \
# 0         10.234.511/0001-21         QS-QUADRA SUL 519  72315-580    DIESEL
# 1         08.385.691/0001-09  AVENIDA PAULO DE FRONTIN  20261-190  GASOLINA
# 2         08.385.691/0001-09  AVENIDA PAULO DE FRONTIN  20261-190    ETANOL
# 3         08.385.691/0001-09  AVENIDA PAULO DE FRONTIN  20261-190    DIESEL
# 4         09.132.997/0001-08                 RUA BAHIA  86025-010  GASOLINA
# ...                      ...                       ...        ...       ...
# 9612976   09.573.096/0001-51     AVENIDA FARIA PEREIRA  38740-000  GASOLINA
# 9612977   09.573.096/0001-51     AVENIDA FARIA PEREIRA  38740-000    ETANOL
# 9612978   09.573.096/0001-51     AVENIDA FARIA PEREIRA  38740-000    DIESEL
# 9612979   10.234.511/0001-21         QS-QUADRA SUL 519  72315-580  GASOLINA
# 9612980   10.234.511/0001-21         QS-QUADRA SUL 519  72315-580    ETANOL
#
#         Data_da_Coleta  Valor_de_Venda  Valor_de_Compra Unidade_de_Medida  \
# 0           2012-08-08           2.070         1.449000        R$ / litro
# 1           2012-08-07           2.799         2.502600        R$ / litro
# 2           2012-08-07           2.289         1.957300        R$ / litro
# 3           2012-08-07           2.049         1.885200        R$ / litro
# 4           2012-08-08           2.699         2.507333        R$ / litro
# ...                ...             ...              ...               ...
# 9612976     2012-08-08           2.950         2.544500        R$ / litro
# 9612977     2012-08-08           2.240         1.464243        R$ / litro
# 9612978     2012-08-08           2.099         1.926900        R$ / litro
# 9612979     2012-08-08           2.830         1.981000        R$ / litro
# 9612980     2012-08-08           2.270         1.589000        R$ / litro
#
#                            Bandeira
# 0        PETROBRAS DISTRIBUIDORA SA
# 1                            RAIZEN
# 2                            RAIZEN
# 3                            RAIZEN
# 4                            BRANCA
# ...                             ...
# 9612976                  RIO BRANCO
# 9612977                  RIO BRANCO
# 9612978                  RIO BRANCO
# 9612979  PETROBRAS DISTRIBUIDORA SA
# 9612980  PETROBRAS DISTRIBUIDORA SA
#
# [9612981 rows x 12 columns]

# %%
# Out:
# C:\Users\tassi\AppData\Local\Temp\ipykernel_33772\2750197057.py:5: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['Semana'] = df['Data_da_Coleta'].dt.week
