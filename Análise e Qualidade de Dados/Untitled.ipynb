# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('dados1.csv', sep = ';')

# %%
df.dtypes
# Out:
# MES               object
# Faturamento        int64
# Novos_clientes     int64
# dtype: object

# %%
df
# Out:
#           MES  Faturamento  Novos_clientes
# 0     Janeiro         2000              15
# 1   Fevereiro         3000              13
# 2       Março         4000              21
# 3       Abril         5000              16
# 4        Maio         3000              10
# 5       Junho         5000              24
# 6       Julho         5000              17
# 7      Agosto         5000              15
# 8    Setembro         6000              23
# 9     Outubro         8000              27
# 10   Novembro        10000              34
# 11   Dezembro        15000              48

# %%
df.plot.scatter(x='MES',y='Faturamento', c = "red")
plt.title('Grafico de Dispersao')
#aumnetar o tamanho do grafico
plt.rcParams['figure.figsize'] = (20, 10)
#alterar o tamanho da fonte
plt.rcParams.update({'font.size': 13})
#colocar uma reta no grafico
plt.show()

# %%
#Grafico de disperçaõ com duas variaveis
df.plot.scatter(x='Faturamento',y='Novos_clientes', c = "Green")
plt.title('Grafico de Dispersao')
#aumnetar o tamanho do grafico
plt.rcParams['figure.figsize'] = (20, 10)
#alterar o tamanho da fonte
plt.rcParams.update({'font.size': 13})
#colocar uma reta no grafico
plt.show()

# %%
#Grafico de disperçaõ com duas variaveis
df.plot.scatter(x='MES',y='Novos_clientes', c = "Green")
plt.title('Grafico de Dispersao')
#aumnetar o tamanho do grafico
plt.rcParams['figure.figsize'] = (20, 10)
#alterar o tamanho da fonte
plt.rcParams.update({'font.size': 13})
#colocar uma reta no grafico
plt.show()
