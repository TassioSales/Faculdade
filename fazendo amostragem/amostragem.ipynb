# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('base_gasolina.csv')

# %%
df
# Out:
#            ano sigla_uf  id_municipio   bairro_revenda cep_revenda  \
# 0         2004       MG       3170701           CENTRO   37002-040
# 1         2004       SP       3554102    VILA SAO JOSE   12070-590
# 2         2004       SP       3554102  PARQUE SAO LUIS   12061-600
# 3         2004       SP       3554102  PARQUE SAO LUIS   12061-600
# 4         2004       SP       3554102  PARQUE SAO LUIS   12061-600
# ...        ...      ...           ...              ...         ...
# 26514819  2021       GO       5208707    JARDIM DA LUZ   74850-545
# 26514820  2021       GO       5208707    JARDIM DA LUZ   74850-545
# 26514821  2021       GO       5208707    JARDIM DA LUZ   74850-545
# 26514822  2021       GO       5208707    JARDIM EUROPA   74325-110
# 26514823  2021       MS       5002704   VILA PROGRESSO   79080-000
#
#                                            endereco_revenda  \
# 0                              PRACA MARECHAL FLORIANO,100
# ...

# %%
df.loc[df['sigla_uf'] == 'DF']
# Out:
#            ano sigla_uf  id_municipio               bairro_revenda  \
# 1261      2004       DF       5300108                   BRAZLANDIA
# 1262      2004       DF       5300108                   BRAZLANDIA
# 1263      2004       DF       5300108                   BRAZLANDIA
# 1264      2004       DF       5300108                  SANTA MARIA
# 1265      2004       DF       5300108                  SANTA MARIA
# ...        ...      ...           ...                          ...
# 26505367  2021       DF       5300108  TAGUATINGA SUL (TAGUATINGA)
# 26505368  2021       DF       5300108  TAGUATINGA SUL (TAGUATINGA)
# 26505369  2021       DF       5300108  TAGUATINGA SUL (TAGUATINGA)
# 26505371  2021       DF       5300108  TAGUATINGA SUL (TAGUATINGA)
# 26505372  2021       DF       5300108  TAGUATINGA SUL (TAGUATINGA)
#
#          cep_revenda                                   endereco_revenda  \
# 1261       72720-000       LOC  CENTRO DE COM E DIVERS, ST NORTE LOTE P
# ...
